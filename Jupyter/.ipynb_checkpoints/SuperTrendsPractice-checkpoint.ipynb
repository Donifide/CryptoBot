# %% [markdown]
# # Packages, dependencies, extras

# %%
#All the thanks to Part Time Larry at https://www.youtube.com/watch?v=1PEyddA1y5E

# %%
#packages
from IPython.display import clear_output
#!pip install schedule

#from config import rh_username,rh_password
from my_config import rh_username,rh_password
import pandas_datareader.data as web
from datetime import datetime
import robin_stocks as r
import schedule,time
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

clear_output()
pd.set_option('display.max_rows', None)

# %%
#Add color for a bit of class.
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
 
#USAGE
# f"{bcolors.OKGREEN}STRING\n{bcolors.ENDC}"

# %% [markdown]
# # Robinhood login & functionality

# %%
#https://robin-stocks.readthedocs.io/en/latest/
login = r.authentication.login(username=rh_username,password=rh_password,store_session=True)
access_token=login['access_token']
token_type=login['token_type']

# %%
#Crypto functions for reference.
"""Contains functions to get information about crypto-currencies."""
import robin_stocks.helper as helper
import robin_stocks.urls as urls

@helper.login_required
def get_crypto_quote(symbol, info=None):
    """Gets information about a crypto including low price, high price, and open price
    :param symbol: The crypto ticker.
    :type symbol: str
    :param info: Will filter the results to have a list of the values that correspond to key that matches info.
    :type info: Optional[str]
    :returns: [dict] If info parameter is left as None then the list will contain a dictionary of key/value pairs for each ticker. \
    Otherwise, it will be a list of strings where the strings are the values of the key that corresponds to info.
    :Dictionary Keys: * ask_price
                      * bid_price
                      * high_price
                      * id
                      * low_price
                      * mark_price
                      * open_price
                      * symbol
                      * volume
 
    """
    id = get_crypto_info(symbol, info='id')
    url = urls.crypto_quote(id)
    data = helper.request_get(url)
    return(helper.filter_data(data, info))

@helper.login_required
def get_crypto_historicals(symbol, interval='hour', span='week', bounds='24_7', info=None):
    """Gets historical information about a crypto including open price, close price, high price, and low price.
    :param symbol: The crypto ticker.
    :type symbol: str
    :param interval: The time between data points. Can be '15second', '5minute', '10minute', 'hour', 'day', or 'week'. Default is 'hour'.
    :type interval: str
    :param span: The entire time frame to collect data points. Can be 'hour', 'day', 'week', 'month', '3month', 'year', or '5year'. Default is 'week'
    :type span: str
    :param bound: The times of day to collect data points. 'Regular' is 6 hours a day, 'trading' is 9 hours a day, \
    'extended' is 16 hours a day, '24_7' is 24 hours a day. Default is '24_7'
    :type bound: str
    :param info: Will filter the results to have a list of the values that correspond to key that matches info.
    :type info: Optional[str]
    :returns: [list] If info parameter is left as None then the list will contain a dictionary of key/value pairs for each ticker. \
    Otherwise, it will be a list of strings where the strings are the values of the key that corresponds to info.
    :Dictionary Keys: * begins_at
                      * open_price
                      * close_price
                      * high_price
                      * low_price
                      * volume
                      * session
                      * interpolated
                      * symbol
    """
    interval_check = ['15second', '5minute', '10minute', 'hour', 'day', 'week']
    span_check = ['hour', 'day', 'week', 'month', '3month', 'year', '5year']
    bounds_check = ['24_7', 'extended', 'regular', 'trading']

    if interval not in interval_check:
        print(
            'ERROR: Interval must be "15second","5minute","10minute","hour","day",or "week"', file=helper.get_output())
        return([None])
    if span not in span_check:
        print('ERROR: Span must be "hour","day","week","month","3month","year",or "5year"', file=helper.get_output())
        return([None])
    if bounds not in bounds_check:
        print('ERROR: Bounds must be "24_7","extended","regular",or "trading"', file=helper.get_output())
        return([None])
    if (bounds == 'extended' or bounds == 'trading') and span != 'day':
        print('ERROR: extended and trading bounds can only be used with a span of "day"', file=helper.get_output())
        return([None])


    symbol = helper.inputs_to_set(symbol)
    id = get_crypto_info(symbol[0], info='id')
    url = urls.crypto_historical(id)
    payload = {'interval': interval,
               'span': span,
               'bounds': bounds}
    data = helper.request_get(url, 'regular', payload)

    histData = []
    cryptoSymbol = data['symbol']
    for subitem in data['data_points']:
        subitem['symbol'] = cryptoSymbol
        histData.append(subitem)

    return(helper.filter_data(histData, info))

# %% [markdown]
# # SuperTrend application

# %%
#SuperTrend
def tr(data):
    data['previous_close'] = data['close'].shift(1)
    data['high-low'] = abs(data['high'] - data['low'])
    data['high-pc'] = abs(data['high'] - data['previous_close'])
    data['low-pc'] = abs(data['low'] - data['previous_close'])

    tr = data[['high-low', 'high-pc', 'low-pc']].max(axis=1)

    return tr

def atr(data, period):
    data['tr'] = tr(data)
    atr = data['tr'].rolling(period).mean()

    return atr

def supertrend(df, period=7, atr_multiplier=3):
    hl2 = (df['high'] + df['low']) / 2
    df['atr'] = atr(df, period)
    df['upperband'] = hl2 + (atr_multiplier * df['atr'])
    df['lowerband'] = hl2 - (atr_multiplier * df['atr'])
    df['in_uptrend'] = True

    for current in range(1, len(df.index)):
        previous = current - 1

        if df['close'][current] > df['upperband'][previous]:
            df['in_uptrend'][current] = True
        elif df['close'][current] < df['lowerband'][previous]:
            df['in_uptrend'][current] = False
        else:
            df['in_uptrend'][current] = df['in_uptrend'][previous]

            if df['in_uptrend'][current] and df['lowerband'][current] < df['lowerband'][previous]:
                df['lowerband'][current] = df['lowerband'][previous]

            if not df['in_uptrend'][current] and df['upperband'][current] > df['upperband'][previous]:
                df['upperband'][current] = df['upperband'][previous]
        
    return df

#Simulation.
#Assumes we're not in a position.
in_position = False

def signal(df):
    global in_position

    last_row_index = len(df.index) - 1
    previous_row_index = last_row_index - 1
    
    #Downtrend > Uptrend: Buy
    if not df['in_uptrend'][previous_row_index] and df['in_uptrend'][last_row_index]:
        print("Buy")
        if not in_position:
            #rh_buy.order(previous_close_price,below_high_price:True)
            print("Bought")
            in_position = True
        else:
            print("already in position, nothing to do")
    
    #Uptrend > Downtrend: Sell
    if df['in_uptrend'][previous_row_index] and not df['in_uptrend'][last_row_index]:
        if in_position:
            print("Sell")
            #rh_sell.order(previous_close_price,pos_return:True)
            print("Sold")
            in_position = False
        else:
            print("You aren't in position, nothing to sell")

def run_bot():
    print(f"\nFetching new data for {datetime.now().isoformat()}")
    df = pd.DataFrame.from_dict(r.crypto.get_crypto_historicals('DOGE', interval='5minute', span='week', bounds='24_7', info=None)).drop(columns=['session','interpolated','symbol']).tail(100).reset_index(drop=True)
    bar = []
    for k,v in df.begins_at.items():
        bar.append([str(time.mktime(datetime.strptime(v,"%Y-%m-%dT%H:%M:%SZ").timetuple()))[:12].replace('.','00'),df.open_price[k],df.high_price[k],df.low_price[k],df.close_price[k],df.volume[k]])
    df = pd.DataFrame(bar[:-1], columns=['timestamp', 'open', 'high', 'low', 'close','volume'])
    df = df.apply(pd.to_numeric)
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    supertrend_data = supertrend(df)
    signal(supertrend_data)
    #pd.DataFrame(supertrend_data)

schedule.every(300).seconds.do(run_bot)


while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# Fetching new data for 2021-09-01T00:48:47.928713
# Fetching new data for 2021-09-01T00:48:58.256031
# Fetching new data for 2021-09-01T00:49:08.594785
# Fetching new data for 2021-09-01T00:49:18.984228
# Fetching new data for 2021-09-01T00:49:29.479705
# Fetching new data for 2021-09-01T00:49:39.783973
# Fetching new data for 2021-09-01T00:49:50.115395
# Fetching new data for 2021-09-01T00:50:00.641083
# Fetching new data for 2021-09-01T00:50:11.199811
# Fetching new data for 2021-09-01T00:50:21.540888
# Fetching new data for 2021-09-01T00:50:38.096766
# Fetching new data for 2021-09-01T00:50:51.215579
# Fetching new data for 2021-09-01T00:51:03.575803
# Fetching new data for 2021-09-01T00:51:16.581919
# Fetching new data for 2021-09-01T00:51:30.124933
# Fetching new data for 2021-09-01T00:51:40.650074
# Fetching new data for 2021-09-01T00:51:51.179036
# Fetching new data for 2021-09-01T00:52:01.633201
# Fetching new data for 2021-09-01T00:52:12.468552
# Fetching new data for 2021-09-01T00:52:22.963611
# Fetching new data for 2021-09-01T00:52:33.406353
# Fetching new data for 2021-09-01T00:52:43.909716
# Fetching new data for 2021-09-01T00:52:54.322515
# Fetching new data for 2021-09-01T00:53:04.715041
# Fetching new data for 2021-09-01T00:53:15.146515
# Fetching new data for 2021-09-01T00:53:25.541202
# Fetching new data for 2021-09-01T00:53:36.001646
# Fetching new data for 2021-09-01T00:53:40.478976
#
# Fetching new data for 2021-09-01T00:53:46.904270
# Fetching new data for 2021-09-01T00:53:57.306724
# Fetching new data for 2021-09-01T00:54:07.724702
# Fetching new data for 2021-09-01T00:54:18.186975
# Fetching new data for 2021-09-01T00:54:28.616853
# Fetching new data for 2021-09-01T00:54:39.036378
# Fetching new data for 2021-09-01T00:54:49.441285
# Fetching new data for 2021-09-01T00:54:59.855358
# Fetching new data for 2021-09-01T00:55:10.283161
# Fetching new data for 2021-09-01T00:55:20.669582
# Fetching new data for 2021-09-01T00:55:31.026365
# Fetching new data for 2021-09-01T00:55:41.446603
# Fetching new data for 2021-09-01T00:55:51.851059
# Fetching new data for 2021-09-01T00:56:02.334064
# Fetching new data for 2021-09-01T00:56:12.741467
# Fetching new data for 2021-09-01T00:56:23.130253
# Fetching new data for 2021-09-01T00:56:33.673430
# Fetching new data for 2021-09-01T00:56:44.098225
# Fetching new data for 2021-09-01T00:56:54.857723
# Fetching new data for 2021-09-01T00:57:05.287932
# Fetching new data for 2021-09-01T00:57:15.725347
# Fetching new data for 2021-09-01T00:57:26.158945
# Fetching new data for 2021-09-01T00:57:36.809952
# Fetching new data for 2021-09-01T00:57:47.254033
# Fetching new data for 2021-09-01T00:57:57.707675
# Fetching new data for 2021-09-01T00:58:08.139769
# Fetching new data for 2021-09-01T00:58:18.561160
# Fetching new data for 2021-09-01T00:58:29.014876
# Fetching new data for 2021-09-01T00:58:39.569386
# Fetching new data for 2021-09-01T00:58:41.055821
#
# Fetching new data for 2021-09-01T00:58:50.496372
# Fetching new data for 2021-09-01T00:59:00.929117
# Fetching new data for 2021-09-01T00:59:11.336401
# Fetching new data for 2021-09-01T00:59:21.795757
# Fetching new data for 2021-09-01T00:59:32.273703
# Fetching new data for 2021-09-01T00:59:42.686068
# Fetching new data for 2021-09-01T00:59:53.100172
# Fetching new data for 2021-09-01T01:00:03.576817
# Fetching new data for 2021-09-01T01:00:13.985726
# Fetching new data for 2021-09-01T01:00:24.462716
# Fetching new data for 2021-09-01T01:00:34.868357
# Fetching new data for 2021-09-01T01:00:45.605998
# Fetching new data for 2021-09-01T01:00:56.044459
# Fetching new data for 2021-09-01T01:01:06.513634
# Fetching new data for 2021-09-01T01:01:16.960179
# Fetching new data for 2021-09-01T01:01:27.372306
# Fetching new data for 2021-09-01T01:01:37.809873
# Fetching new data for 2021-09-01T01:01:48.260921
# Fetching new data for 2021-09-01T01:01:58.671916
# Fetching new data for 2021-09-01T01:02:09.101592
# Fetching new data for 2021-09-01T01:02:19.564954
# Fetching new data for 2021-09-01T01:02:29.972438
# Fetching new data for 2021-09-01T01:02:40.444043
# Fetching new data for 2021-09-01T01:02:50.892559
# Fetching new data for 2021-09-01T01:03:01.323535
# Fetching new data for 2021-09-01T01:03:11.842137
# Fetching new data for 2021-09-01T01:03:22.280063
# Fetching new data for 2021-09-01T01:03:32.755092
# Fetching new data for 2021-09-01T01:03:42.191391
#
# Fetching new data for 2021-09-01T01:03:43.589070
# Fetching new data for 2021-09-01T01:03:53.988872
# Fetching new data for 2021-09-01T01:04:04.439460
# Fetching new data for 2021-09-01T01:04:14.965192
# Fetching new data for 2021-09-01T01:04:25.370384
# Fetching new data for 2021-09-01T01:04:35.801344
# Fetching new data for 2021-09-01T01:04:46.216607
# Fetching new data for 2021-09-01T01:04:56.982274
# Fetching new data for 2021-09-01T01:05:07.607451
# Fetching new data for 2021-09-01T01:05:18.061437
# Fetching new data for 2021-09-01T01:05:28.459725
# Fetching new data for 2021-09-01T01:05:38.925332
# Fetching new data for 2021-09-01T01:05:49.360497
# Fetching new data for 2021-09-01T01:05:59.760617
# Fetching new data for 2021-09-01T01:06:10.167148
# Fetching new data for 2021-09-01T01:06:20.681205
# Fetching new data for 2021-09-01T01:06:31.072920
# Fetching new data for 2021-09-01T01:06:41.430962
# Fetching new data for 2021-09-01T01:06:51.779258
# Fetching new data for 2021-09-01T01:07:02.410862
# Fetching new data for 2021-09-01T01:07:12.798304
# Fetching new data for 2021-09-01T01:07:23.133207
# Fetching new data for 2021-09-01T01:07:33.559450
# Fetching new data for 2021-09-01T01:07:43.894299
# Fetching new data for 2021-09-01T01:07:54.242196
# Fetching new data for 2021-09-01T01:08:04.583662
# Fetching new data for 2021-09-01T01:08:15.020455
# Fetching new data for 2021-09-01T01:08:25.359507
# Fetching new data for 2021-09-01T01:08:35.723927
# Fetching new data for 2021-09-01T01:08:43.049185
#
# Fetching new data for 2021-09-01T01:08:46.390668
# Fetching new data for 2021-09-01T01:08:56.798458
# Fetching new data for 2021-09-01T01:09:07.167958
# Fetching new data for 2021-09-01T01:09:17.772311
# Fetching new data for 2021-09-01T01:09:28.119129
# Fetching new data for 2021-09-01T01:09:38.471452
# Fetching new data for 2021-09-01T01:09:48.821098
# Fetching new data for 2021-09-01T01:09:59.151814
# Fetching new data for 2021-09-01T01:10:09.511235
# Fetching new data for 2021-09-01T01:10:19.856644
# Fetching new data for 2021-09-01T01:10:30.216651
# Fetching new data for 2021-09-01T01:10:40.557140
# Fetching new data for 2021-09-01T01:10:50.965585
# Fetching new data for 2021-09-01T01:11:01.368172
# Fetching new data for 2021-09-01T01:11:11.752905
# Fetching new data for 2021-09-01T01:11:22.528772
# Fetching new data for 2021-09-01T01:11:33.017610
# Fetching new data for 2021-09-01T01:11:43.452472
# Fetching new data for 2021-09-01T01:11:53.917253
# Fetching new data for 2021-09-01T01:12:04.368232
# Fetching new data for 2021-09-01T01:12:14.814600
# Fetching new data for 2021-09-01T01:12:25.232073
# Fetching new data for 2021-09-01T01:12:35.764919
# Fetching new data for 2021-09-01T01:12:46.214089
# Fetching new data for 2021-09-01T01:12:56.676418
# Fetching new data for 2021-09-01T01:13:07.126379
# Fetching new data for 2021-09-01T01:13:17.601289
# Fetching new data for 2021-09-01T01:13:28.374929
# Fetching new data for 2021-09-01T01:13:38.801655
# Fetching new data for 2021-09-01T01:13:44.266105
#
# Fetching new data for 2021-09-01T01:13:49.689768
# Fetching new data for 2021-09-01T01:14:00.178452
# Fetching new data for 2021-09-01T01:14:10.676292
# Fetching new data for 2021-09-01T01:14:21.179434
# Fetching new data for 2021-09-01T01:14:31.671958
# Fetching new data for 2021-09-01T01:14:42.225168
# Fetching new data for 2021-09-01T01:14:52.687578
# Fetching new data for 2021-09-01T01:15:03.218362
# Fetching new data for 2021-09-01T01:15:13.701386
# Fetching new data for 2021-09-01T01:15:24.237349
# Fetching new data for 2021-09-01T01:15:34.742047
# Fetching new data for 2021-09-01T01:15:45.276728
# Fetching new data for 2021-09-01T01:15:55.854429
# Fetching new data for 2021-09-01T01:16:06.474127
# Fetching new data for 2021-09-01T01:16:16.988310
# Fetching new data for 2021-09-01T01:16:27.485781
# Fetching new data for 2021-09-01T01:16:37.999036
# Fetching new data for 2021-09-01T01:16:48.498771
# Fetching new data for 2021-09-01T01:16:58.998669
# Fetching new data for 2021-09-01T01:17:09.512875
# Fetching new data for 2021-09-01T01:17:20.035021
# Fetching new data for 2021-09-01T01:17:30.583964
# Fetching new data for 2021-09-01T01:17:41.066710
# Fetching new data for 2021-09-01T01:17:51.612236
# Fetching new data for 2021-09-01T01:18:02.099713
# Fetching new data for 2021-09-01T01:18:12.616218
# Fetching new data for 2021-09-01T01:18:23.132723
# Fetching new data for 2021-09-01T01:18:33.599108
# Fetching new data for 2021-09-01T01:18:44.085684
# Fetching new data for 2021-09-01T01:18:45.522231
#
# Fetching new data for 2021-09-01T01:18:54.982220
# Fetching new data for 2021-09-01T01:19:05.450064
# Fetching new data for 2021-09-01T01:19:15.947100
# Fetching new data for 2021-09-01T01:19:26.893026
# Fetching new data for 2021-09-01T01:19:37.396895
# Fetching new data for 2021-09-01T01:19:47.890965
# Fetching new data for 2021-09-01T01:19:58.346529
# Fetching new data for 2021-09-01T01:20:08.796496
# Fetching new data for 2021-09-01T01:20:19.246309
# Fetching new data for 2021-09-01T01:20:29.689746
# Fetching new data for 2021-09-01T01:20:40.231865
# Fetching new data for 2021-09-01T01:20:50.697997
# Fetching new data for 2021-09-01T01:21:01.220551
# Fetching new data for 2021-09-01T01:21:11.678365
# Fetching new data for 2021-09-01T01:21:22.133988
# Fetching new data for 2021-09-01T01:21:32.580872
# Fetching new data for 2021-09-01T01:21:43.020713
# Fetching new data for 2021-09-01T01:21:53.677591
# Fetching new data for 2021-09-01T01:22:04.377060
# Fetching new data for 2021-09-01T01:22:14.838542
# Fetching new data for 2021-09-01T01:22:25.297630
# Fetching new data for 2021-09-01T01:22:35.770720
# Fetching new data for 2021-09-01T01:22:46.209398
# Fetching new data for 2021-09-01T01:22:56.669196
# Fetching new data for 2021-09-01T01:23:07.107647
# Fetching new data for 2021-09-01T01:23:17.558253
# Fetching new data for 2021-09-01T01:23:28.073764
# Fetching new data for 2021-09-01T01:23:38.528583
# Fetching new data for 2021-09-01T01:23:45.974473
#
# Fetching new data for 2021-09-01T01:23:49.406076
# Fetching new data for 2021-09-01T01:24:00.047641
# Fetching new data for 2021-09-01T01:24:10.538413
# Fetching new data for 2021-09-01T01:24:20.988943
# Fetching new data for 2021-09-01T01:24:31.459020
# Fetching new data for 2021-09-01T01:24:41.922985
# Fetching new data for 2021-09-01T01:24:52.355455
# Fetching new data for 2021-09-01T01:25:02.784243
# Fetching new data for 2021-09-01T01:25:13.272127
# Fetching new data for 2021-09-01T01:25:23.742544
# Fetching new data for 2021-09-01T01:25:34.241577
# Fetching new data for 2021-09-01T01:25:44.683023
# Fetching new data for 2021-09-01T01:25:55.104545
# Fetching new data for 2021-09-01T01:26:05.520913
# Fetching new data for 2021-09-01T01:26:16.156056
# Fetching new data for 2021-09-01T01:26:26.608176
# Fetching new data for 2021-09-01T01:26:37.060066
# Fetching new data for 2021-09-01T01:26:47.466381
# Fetching new data for 2021-09-01T01:26:57.863372
# Fetching new data for 2021-09-01T01:27:08.619147
# Fetching new data for 2021-09-01T01:27:19.045554
# Fetching new data for 2021-09-01T01:27:29.508067
# Fetching new data for 2021-09-01T01:27:39.847756
# Fetching new data for 2021-09-01T01:27:50.553138
# Fetching new data for 2021-09-01T01:28:00.961499
# Fetching new data for 2021-09-01T01:28:11.323850
# Fetching new data for 2021-09-01T01:28:21.866033
# Fetching new data for 2021-09-01T01:28:32.266005
# Fetching new data for 2021-09-01T01:28:42.614987
# Fetching new data for 2021-09-01T01:28:46.937038
#
# Fetching new data for 2021-09-01T01:28:53.286491
# Fetching new data for 2021-09-01T01:29:03.636323
# Fetching new data for 2021-09-01T01:29:14.042608
# Fetching new data for 2021-09-01T01:29:24.390116
# Fetching new data for 2021-09-01T01:29:34.787661
# Fetching new data for 2021-09-01T01:29:45.142683
# Fetching new data for 2021-09-01T01:29:55.486245
# Fetching new data for 2021-09-01T01:30:05.890357
# Fetching new data for 2021-09-01T01:30:16.298669
# Fetching new data for 2021-09-01T01:30:26.852452
# Fetching new data for 2021-09-01T01:30:37.251108
# Fetching new data for 2021-09-01T01:30:47.673196
# Fetching new data for 2021-09-01T01:30:58.049353
# Fetching new data for 2021-09-01T01:31:08.413214
# Fetching new data for 2021-09-01T01:31:18.768734
# Fetching new data for 2021-09-01T01:31:29.133162
# Fetching new data for 2021-09-01T01:31:39.483754
# Fetching new data for 2021-09-01T01:31:49.851172
# Fetching new data for 2021-09-01T01:32:00.252616
# Fetching new data for 2021-09-01T01:32:10.622663
# Fetching new data for 2021-09-01T01:32:20.955659
# Fetching new data for 2021-09-01T01:32:31.308139
# Fetching new data for 2021-09-01T01:32:41.929960
# Fetching new data for 2021-09-01T01:32:52.256832
# Fetching new data for 2021-09-01T01:33:02.605007
# Fetching new data for 2021-09-01T01:33:13.001230
# Fetching new data for 2021-09-01T01:33:23.337002
# Fetching new data for 2021-09-01T01:33:33.676595
# Fetching new data for 2021-09-01T01:33:44.021787
# Fetching new data for 2021-09-01T01:33:47.343388
#
# Fetching new data for 2021-09-01T01:33:54.745706
# Fetching new data for 2021-09-01T01:34:05.117669
# Fetching new data for 2021-09-01T01:34:15.542691
# Fetching new data for 2021-09-01T01:34:25.896202
# Fetching new data for 2021-09-01T01:34:36.404033
# Fetching new data for 2021-09-01T01:34:46.918840
# Fetching new data for 2021-09-01T01:34:57.261400
# Fetching new data for 2021-09-01T01:35:07.600624
# Fetching new data for 2021-09-01T01:35:17.947731
# Fetching new data for 2021-09-01T01:35:28.297615
# Fetching new data for 2021-09-01T01:35:38.717780
# Fetching new data for 2021-09-01T01:35:49.109826
# Fetching new data for 2021-09-01T01:35:59.692364
# Fetching new data for 2021-09-01T01:36:10.249388
# Fetching new data for 2021-09-01T01:36:20.700276
# Fetching new data for 2021-09-01T01:36:31.202217
# Fetching new data for 2021-09-01T01:36:41.934332
# Fetching new data for 2021-09-01T01:36:52.620753
# Fetching new data for 2021-09-01T01:37:03.049256
# Fetching new data for 2021-09-01T01:37:13.451497
# Fetching new data for 2021-09-01T01:37:23.937805
# Fetching new data for 2021-09-01T01:37:34.390003
# Fetching new data for 2021-09-01T01:37:44.830483
# Fetching new data for 2021-09-01T01:37:55.246237
# Fetching new data for 2021-09-01T01:38:05.695717
# Fetching new data for 2021-09-01T01:38:16.098232
# Fetching new data for 2021-09-01T01:38:26.578217
# Fetching new data for 2021-09-01T01:38:36.997043
# Fetching new data for 2021-09-01T01:38:47.454320
# Fetching new data for 2021-09-01T01:38:49.207923
#
# Fetching new data for 2021-09-01T01:38:58.661718
# Fetching new data for 2021-09-01T01:39:09.073756
# Fetching new data for 2021-09-01T01:39:19.492480
# Fetching new data for 2021-09-01T01:39:29.883879
# Fetching new data for 2021-09-01T01:39:40.328484
# Fetching new data for 2021-09-01T01:39:50.791203
# Fetching new data for 2021-09-01T01:40:01.222267
# Fetching new data for 2021-09-01T01:40:11.668373
# Fetching new data for 2021-09-01T01:40:22.094619
# Fetching new data for 2021-09-01T01:40:32.521410
# Fetching new data for 2021-09-01T01:40:42.983963
# Fetching new data for 2021-09-01T01:40:53.409246
# Fetching new data for 2021-09-01T01:41:04.321512
# Fetching new data for 2021-09-01T01:41:14.780958
# Fetching new data for 2021-09-01T01:41:25.188798
# Fetching new data for 2021-09-01T01:41:35.615451
# Fetching new data for 2021-09-01T01:41:46.193460
# Fetching new data for 2021-09-01T01:41:56.586036
# Fetching new data for 2021-09-01T01:42:06.949410
# Fetching new data for 2021-09-01T01:42:17.342645
# Fetching new data for 2021-09-01T01:42:27.763956
# Fetching new data for 2021-09-01T01:42:38.179974
# Fetching new data for 2021-09-01T01:42:48.685765
# Fetching new data for 2021-09-01T01:42:59.111493
# Fetching new data for 2021-09-01T01:43:09.510728
# Fetching new data for 2021-09-01T01:43:19.910494
# Fetching new data for 2021-09-01T01:43:30.492643
# Fetching new data for 2021-09-01T01:43:40.910502
# Fetching new data for 2021-09-01T01:43:50.409784
#
# Fetching new data for 2021-09-01T01:43:51.903974
# Fetching new data for 2021-09-01T01:44:02.491392
# Fetching new data for 2021-09-01T01:44:14.991587
# Fetching new data for 2021-09-01T01:44:25.403590
# Fetching new data for 2021-09-01T01:44:35.794723
# Fetching new data for 2021-09-01T01:44:46.240861
# Fetching new data for 2021-09-01T01:44:56.679225
# Fetching new data for 2021-09-01T01:45:07.090577
# Fetching new data for 2021-09-01T01:45:17.480664
# Fetching new data for 2021-09-01T01:45:27.873854
# Fetching new data for 2021-09-01T01:45:38.240214
# Fetching new data for 2021-09-01T01:45:48.727597
# Fetching new data for 2021-09-01T01:45:59.117548
# Fetching new data for 2021-09-01T01:46:09.548045
# Fetching new data for 2021-09-01T01:46:19.931377
# Fetching new data for 2021-09-01T01:46:30.304055
# Fetching new data for 2021-09-01T01:46:40.697270
# Fetching new data for 2021-09-01T01:46:51.105253
# Fetching new data for 2021-09-01T01:47:01.477694
# Fetching new data for 2021-09-01T01:47:11.901559
# Fetching new data for 2021-09-01T01:47:22.291515
# Fetching new data for 2021-09-01T01:47:32.704095
# Fetching new data for 2021-09-01T01:47:43.092060
# Fetching new data for 2021-09-01T01:47:53.461064
# Fetching new data for 2021-09-01T01:48:03.851147
# Fetching new data for 2021-09-01T01:48:14.223721
# Fetching new data for 2021-09-01T01:48:24.569544
# Fetching new data for 2021-09-01T01:48:34.981661
# Fetching new data for 2021-09-01T01:48:45.363794
# Fetching new data for 2021-09-01T01:48:51.700360
#
# Fetching new data for 2021-09-01T01:48:57.087805
# Fetching new data for 2021-09-01T01:49:07.479105
# Fetching new data for 2021-09-01T01:49:17.875334
# Fetching new data for 2021-09-01T01:49:28.375082
# Fetching new data for 2021-09-01T01:49:38.794220
# Fetching new data for 2021-09-01T01:49:49.150476
# Fetching new data for 2021-09-01T01:49:59.520447
# Fetching new data for 2021-09-01T01:50:09.890743
# Fetching new data for 2021-09-01T01:50:20.574799
# Fetching new data for 2021-09-01T01:50:30.938532
# Fetching new data for 2021-09-01T01:50:41.384330
# Fetching new data for 2021-09-01T01:50:51.782444
# Fetching new data for 2021-09-01T01:51:02.186319
# Fetching new data for 2021-09-01T01:51:12.580601
# Fetching new data for 2021-09-01T01:51:22.973645
# Fetching new data for 2021-09-01T01:51:33.452709
# Fetching new data for 2021-09-01T01:51:43.832045
# Fetching new data for 2021-09-01T01:51:54.251886
# Fetching new data for 2021-09-01T01:52:04.649222
# Fetching new data for 2021-09-01T01:52:15.008592
# Fetching new data for 2021-09-01T01:52:25.383496
# Fetching new data for 2021-09-01T01:52:35.782753
# Fetching new data for 2021-09-01T01:52:46.162564
# Fetching new data for 2021-09-01T01:52:56.547969
# Fetching new data for 2021-09-01T01:53:06.916169
# Fetching new data for 2021-09-01T01:53:17.296129
# Fetching new data for 2021-09-01T01:53:27.685605
# Fetching new data for 2021-09-01T01:53:38.121493
# Fetching new data for 2021-09-01T01:53:48.496787
# Fetching new data for 2021-09-01T01:53:52.873000
#
# Fetching new data for 2021-09-01T01:53:59.235525
# Fetching new data for 2021-09-01T01:54:09.921678
# Fetching new data for 2021-09-01T01:54:20.306638
# Fetching new data for 2021-09-01T01:54:30.702180
# Fetching new data for 2021-09-01T01:54:41.183662
# Fetching new data for 2021-09-01T01:54:51.596009
# Fetching new data for 2021-09-01T01:55:01.992214
# Fetching new data for 2021-09-01T01:55:12.406079
# Fetching new data for 2021-09-01T01:55:22.808566
# Fetching new data for 2021-09-01T01:55:33.220699
# Fetching new data for 2021-09-01T01:55:43.610682
# Fetching new data for 2021-09-01T01:55:54.095358
# Fetching new data for 2021-09-01T01:56:04.477479
# Fetching new data for 2021-09-01T01:56:14.847729
# Fetching new data for 2021-09-01T01:56:25.252442
# Fetching new data for 2021-09-01T01:56:35.663186
# Fetching new data for 2021-09-01T01:56:46.092419
# Fetching new data for 2021-09-01T01:56:56.444487
# Fetching new data for 2021-09-01T01:57:06.817059
# Fetching new data for 2021-09-01T01:57:17.221024
# Fetching new data for 2021-09-01T01:57:27.635370
# Fetching new data for 2021-09-01T01:57:38.021682
# Fetching new data for 2021-09-01T01:57:48.458551
# Fetching new data for 2021-09-01T01:57:58.826453
# Fetching new data for 2021-09-01T01:58:09.217479
# Fetching new data for 2021-09-01T01:58:19.620454
# Fetching new data for 2021-09-01T01:58:29.993361
# Fetching new data for 2021-09-01T01:58:40.368337
# Fetching new data for 2021-09-01T01:58:51.327301
# Fetching new data for 2021-09-01T01:58:53.697413
#
# Fetching new data for 2021-09-01T01:59:02.069478
# Fetching new data for 2021-09-01T01:59:12.562778
# Fetching new data for 2021-09-01T01:59:22.966506
# Fetching new data for 2021-09-01T01:59:33.352056
# Fetching new data for 2021-09-01T01:59:43.717641
# Fetching new data for 2021-09-01T01:59:54.154087
# Fetching new data for 2021-09-01T02:00:04.551210
# Fetching new data for 2021-09-01T02:00:14.920262
# Fetching new data for 2021-09-01T02:00:25.279491
# Fetching new data for 2021-09-01T02:00:35.671046
# Fetching new data for 2021-09-01T02:00:46.068937
# Fetching new data for 2021-09-01T02:00:56.482168
# Fetching new data for 2021-09-01T02:01:06.868663
# Fetching new data for 2021-09-01T02:01:17.249390
# Fetching new data for 2021-09-01T02:01:27.659287
# Fetching new data for 2021-09-01T02:01:38.034419
# Fetching new data for 2021-09-01T02:01:48.416173
# Fetching new data for 2021-09-01T02:01:58.816047
# Fetching new data for 2021-09-01T02:02:09.315926
# Fetching new data for 2021-09-01T02:02:19.715821
# Fetching new data for 2021-09-01T02:02:30.103186
# Fetching new data for 2021-09-01T02:02:40.459612
# Fetching new data for 2021-09-01T02:02:50.840243
# Fetching new data for 2021-09-01T02:03:01.219143
# Fetching new data for 2021-09-01T02:03:11.646454
# Fetching new data for 2021-09-01T02:03:22.167958
# Fetching new data for 2021-09-01T02:03:32.544002
# Fetching new data for 2021-09-01T02:03:42.955851
# Fetching new data for 2021-09-01T02:03:53.358088
# Fetching new data for 2021-09-01T02:03:54.697867
#
# Fetching new data for 2021-09-01T02:04:04.139292
# Fetching new data for 2021-09-01T02:04:14.517052
# Fetching new data for 2021-09-01T02:04:25.163035
# Fetching new data for 2021-09-01T02:04:35.566852
# Fetching new data for 2021-09-01T02:04:45.953275
# Fetching new data for 2021-09-01T02:04:56.343559
# Fetching new data for 2021-09-01T02:05:06.753544
# Fetching new data for 2021-09-01T02:05:17.162314
# Fetching new data for 2021-09-01T02:05:27.542713
# Fetching new data for 2021-09-01T02:05:37.914113
# Fetching new data for 2021-09-01T02:05:48.344091
# Fetching new data for 2021-09-01T02:05:58.710108
# Fetching new data for 2021-09-01T02:06:09.074098
# Fetching new data for 2021-09-01T02:06:19.453420
# Fetching new data for 2021-09-01T02:06:30.010306
# Fetching new data for 2021-09-01T02:06:40.409255
# Fetching new data for 2021-09-01T02:06:50.782842
# Fetching new data for 2021-09-01T02:07:01.151106
# Fetching new data for 2021-09-01T02:07:11.535331
# Fetching new data for 2021-09-01T02:07:21.900058
# Fetching new data for 2021-09-01T02:07:32.280187
# Fetching new data for 2021-09-01T02:07:42.634420
# Fetching new data for 2021-09-01T02:07:53.032602
# Fetching new data for 2021-09-01T02:08:03.412810
# Fetching new data for 2021-09-01T02:08:13.777682
# Fetching new data for 2021-09-01T02:08:24.259037
# Fetching new data for 2021-09-01T02:08:34.644364
# Fetching new data for 2021-09-01T02:08:45.057591
# Fetching new data for 2021-09-01T02:08:55.457216
#
# Fetching new data for 2021-09-01T02:08:55.809869
# Fetching new data for 2021-09-01T02:09:06.166658
# Fetching new data for 2021-09-01T02:09:16.546647
# Fetching new data for 2021-09-01T02:09:26.893631
# Fetching new data for 2021-09-01T02:09:37.279979
# Fetching new data for 2021-09-01T02:09:47.707892
# Fetching new data for 2021-09-01T02:09:58.093223
# Fetching new data for 2021-09-01T02:10:08.468122
# Fetching new data for 2021-09-01T02:10:18.832147
# Fetching new data for 2021-09-01T02:10:29.242024
# Fetching new data for 2021-09-01T02:10:39.665371
# Fetching new data for 2021-09-01T02:10:50.059752
# Fetching new data for 2021-09-01T02:11:00.477629
# Fetching new data for 2021-09-01T02:11:10.871181
# Fetching new data for 2021-09-01T02:11:21.242125
# Fetching new data for 2021-09-01T02:11:31.677215
# Fetching new data for 2021-09-01T02:11:42.077062
# Fetching new data for 2021-09-01T02:11:52.454204
# Fetching new data for 2021-09-01T02:12:02.880743
# Fetching new data for 2021-09-01T02:12:13.294423
# Fetching new data for 2021-09-01T02:12:23.676504
# Fetching new data for 2021-09-01T02:12:34.041987
# Fetching new data for 2021-09-01T02:12:44.786193
# Fetching new data for 2021-09-01T02:12:55.580027
# Fetching new data for 2021-09-01T02:13:06.068059
# Fetching new data for 2021-09-01T02:13:16.467765
# Fetching new data for 2021-09-01T02:13:26.863062
# Fetching new data for 2021-09-01T02:13:37.276262
# Fetching new data for 2021-09-01T02:13:47.942850
# Fetching new data for 2021-09-01T02:13:56.316651
# Fetching new data for 2021-09-01T02:13:58.683520
# Fetching new data for 2021-09-01T02:14:09.055465
# Fetching new data for 2021-09-01T02:14:19.462662
# Fetching new data for 2021-09-01T02:14:29.824824
# Fetching new data for 2021-09-01T02:14:40.215619
# Fetching new data for 2021-09-01T02:14:50.674679
# Fetching new data for 2021-09-01T02:15:01.078320
# Fetching new data for 2021-09-01T02:15:11.453794
# Fetching new data for 2021-09-01T02:15:21.824095
# Fetching new data for 2021-09-01T02:15:32.223996
# Fetching new data for 2021-09-01T02:15:42.673895
# Fetching new data for 2021-09-01T02:15:53.139323
# Fetching new data for 2021-09-01T02:16:03.523024
# Fetching new data for 2021-09-01T02:16:13.903884
# Fetching new data for 2021-09-01T02:16:24.275517
# Fetching new data for 2021-09-01T02:16:34.917956
# Fetching new data for 2021-09-01T02:16:45.297398
# Fetching new data for 2021-09-01T02:16:55.760362
# Fetching new data for 2021-09-01T02:17:06.310194
# Fetching new data for 2021-09-01T02:17:16.670415
# Fetching new data for 2021-09-01T02:17:27.072409
# Fetching new data for 2021-09-01T02:17:37.476263
# Fetching new data for 2021-09-01T02:17:47.856083
# Fetching new data for 2021-09-01T02:17:58.229254
# Fetching new data for 2021-09-01T02:18:08.819422
# Fetching new data for 2021-09-01T02:18:19.208531
# Fetching new data for 2021-09-01T02:18:29.609179
# Fetching new data for 2021-09-01T02:18:40.392109
# Fetching new data for 2021-09-01T02:18:50.758626
# Fetching new data for 2021-09-01T02:18:57.148527
#
# Fetching new data for 2021-09-01T02:19:01.603165
# Fetching new data for 2021-09-01T02:19:12.008085
# Fetching new data for 2021-09-01T02:19:22.374899
# Fetching new data for 2021-09-01T02:19:32.743382
# Fetching new data for 2021-09-01T02:19:43.124567
# Fetching new data for 2021-09-01T02:19:53.511900
# Fetching new data for 2021-09-01T02:20:03.879236
# Fetching new data for 2021-09-01T02:20:14.257535
# Fetching new data for 2021-09-01T02:20:24.649007
# Fetching new data for 2021-09-01T02:20:35.018995
# Fetching new data for 2021-09-01T02:20:45.455593
# Fetching new data for 2021-09-01T02:20:55.833703
# Fetching new data for 2021-09-01T02:21:06.248830
# Fetching new data for 2021-09-01T02:21:16.804826
# Fetching new data for 2021-09-01T02:21:27.219234
# Fetching new data for 2021-09-01T02:21:37.604249
# Fetching new data for 2021-09-01T02:21:48.003667
# Fetching new data for 2021-09-01T02:21:58.376421
# Fetching new data for 2021-09-01T02:22:08.799946
# Fetching new data for 2021-09-01T02:22:19.189953
# Fetching new data for 2021-09-01T02:22:29.587074
# Fetching new data for 2021-09-01T02:22:39.957850
# Fetching new data for 2021-09-01T02:22:50.351094
# Fetching new data for 2021-09-01T02:23:00.737633
# Fetching new data for 2021-09-01T02:23:11.200103
# Fetching new data for 2021-09-01T02:23:21.649779
# Fetching new data for 2021-09-01T02:23:32.333122
# Fetching new data for 2021-09-01T02:23:42.850258
# Fetching new data for 2021-09-01T02:23:53.282656
# Fetching new data for 2021-09-01T02:23:57.652474
#
# Fetching new data for 2021-09-01T02:24:04.005228
# Fetching new data for 2021-09-01T02:24:14.376298
# Fetching new data for 2021-09-01T02:24:24.826272
# Fetching new data for 2021-09-01T02:24:35.202461
# Fetching new data for 2021-09-01T02:24:45.577190
# Fetching new data for 2021-09-01T02:24:55.998299
# Fetching new data for 2021-09-01T02:25:06.369239
# Fetching new data for 2021-09-01T02:25:16.714958
# Fetching new data for 2021-09-01T02:25:27.185979
# Fetching new data for 2021-09-01T02:25:37.895331
# Fetching new data for 2021-09-01T02:25:48.295696
# Fetching new data for 2021-09-01T02:25:58.666077
# Fetching new data for 2021-09-01T02:26:09.021419
# Fetching new data for 2021-09-01T02:26:19.436461
# Fetching new data for 2021-09-01T02:26:29.796815
# Fetching new data for 2021-09-01T02:26:40.146935
# Fetching new data for 2021-09-01T02:26:50.530271
# Fetching new data for 2021-09-01T02:27:00.924108
# Fetching new data for 2021-09-01T02:27:12.343205
# Fetching new data for 2021-09-01T02:27:22.739589
# Fetching new data for 2021-09-01T02:27:33.141353
# Fetching new data for 2021-09-01T02:27:43.532848
# Fetching new data for 2021-09-01T02:27:53.912865
# Fetching new data for 2021-09-01T02:28:04.360032
# Fetching new data for 2021-09-01T02:28:14.729891
# Fetching new data for 2021-09-01T02:28:25.096176
# Fetching new data for 2021-09-01T02:28:35.472079
# Fetching new data for 2021-09-01T02:28:45.811627
# Fetching new data for 2021-09-01T02:28:56.274349
# Fetching new data for 2021-09-01T02:28:58.594319
#
# Fetching new data for 2021-09-01T02:29:07.031776
# Fetching new data for 2021-09-01T02:29:17.594061
# Fetching new data for 2021-09-01T02:29:27.981160
# Fetching new data for 2021-09-01T02:29:38.345338
# Fetching new data for 2021-09-01T02:29:48.722740
# Fetching new data for 2021-09-01T02:29:59.131417
# Fetching new data for 2021-09-01T02:30:09.517423
# Fetching new data for 2021-09-01T02:30:19.909299
# Fetching new data for 2021-09-01T02:30:30.337267
# Fetching new data for 2021-09-01T02:30:40.737048
# Fetching new data for 2021-09-01T02:30:51.143776
# Fetching new data for 2021-09-01T02:31:01.536338
# Fetching new data for 2021-09-01T02:31:11.943513
# Fetching new data for 2021-09-01T02:31:22.343347
# Fetching new data for 2021-09-01T02:31:32.743128
# Fetching new data for 2021-09-01T02:31:43.138566
# Fetching new data for 2021-09-01T02:31:53.724022
# Fetching new data for 2021-09-01T02:32:04.091437
# Fetching new data for 2021-09-01T02:32:14.545242
# Fetching new data for 2021-09-01T02:32:24.956931
# Fetching new data for 2021-09-01T02:32:35.372276
# Fetching new data for 2021-09-01T02:32:45.733114
# Fetching new data for 2021-09-01T02:32:56.117845
# Fetching new data for 2021-09-01T02:33:06.532674
# Fetching new data for 2021-09-01T02:33:16.894350
# Fetching new data for 2021-09-01T02:33:27.267352
# Fetching new data for 2021-09-01T02:33:37.656784
# Fetching new data for 2021-09-01T02:33:48.043669
# Fetching new data for 2021-09-01T02:33:58.817205
# Fetching new data for 2021-09-01T02:34:00.166801
#
# Fetching new data for 2021-09-01T02:34:09.547099
# Fetching new data for 2021-09-01T02:34:19.920997
# Fetching new data for 2021-09-01T02:34:30.303889
# Fetching new data for 2021-09-01T02:34:40.729747
# Fetching new data for 2021-09-01T02:34:51.157962
# Fetching new data for 2021-09-01T02:35:01.582671
# Fetching new data for 2021-09-01T02:35:12.028887
# Fetching new data for 2021-09-01T02:35:22.389489
# Fetching new data for 2021-09-01T02:35:32.873843
# Fetching new data for 2021-09-01T02:35:43.260024
# Fetching new data for 2021-09-01T02:35:53.627659
# Fetching new data for 2021-09-01T02:36:04.267782
# Fetching new data for 2021-09-01T02:36:14.864664
# Fetching new data for 2021-09-01T02:36:25.231028
# Fetching new data for 2021-09-01T02:36:35.635752
# Fetching new data for 2021-09-01T02:36:46.051681
# Fetching new data for 2021-09-01T02:36:56.423659
# Fetching new data for 2021-09-01T02:37:06.814824
# Fetching new data for 2021-09-01T02:37:17.185163
# Fetching new data for 2021-09-01T02:37:27.549199
# Fetching new data for 2021-09-01T02:37:37.913307
# Fetching new data for 2021-09-01T02:37:48.284378
# Fetching new data for 2021-09-01T02:37:58.813495
# Fetching new data for 2021-09-01T02:38:09.265668
# Fetching new data for 2021-09-01T02:38:19.893930
# Fetching new data for 2021-09-01T02:38:30.243841
# Fetching new data for 2021-09-01T02:38:40.686833
# Fetching new data for 2021-09-01T02:38:51.094014
# Fetching new data for 2021-09-01T02:39:01.470948
#
# Fetching new data for 2021-09-01T02:39:01.859260
# Fetching new data for 2021-09-01T02:39:12.220940
# Fetching new data for 2021-09-01T02:39:22.579416
# Fetching new data for 2021-09-01T02:39:33.007189
# Fetching new data for 2021-09-01T02:39:43.404075
# Fetching new data for 2021-09-01T02:39:53.754065
# Fetching new data for 2021-09-01T02:40:04.120292
# Fetching new data for 2021-09-01T02:40:14.514139
# Fetching new data for 2021-09-01T02:40:25.145489
# Fetching new data for 2021-09-01T02:40:35.540421
# Fetching new data for 2021-09-01T02:40:46.013468
# Fetching new data for 2021-09-01T02:40:56.414060
# Fetching new data for 2021-09-01T02:41:06.820316
# Fetching new data for 2021-09-01T02:41:17.377200
# Fetching new data for 2021-09-01T02:41:27.753674
# Fetching new data for 2021-09-01T02:41:38.113931
# Fetching new data for 2021-09-01T02:41:48.508184
# Fetching new data for 2021-09-01T02:41:58.946062
# Fetching new data for 2021-09-01T02:42:09.367262
# Fetching new data for 2021-09-01T02:42:19.753496
# Fetching new data for 2021-09-01T02:42:30.369842
# Fetching new data for 2021-09-01T02:42:40.763832
# Fetching new data for 2021-09-01T02:42:51.218106
# Fetching new data for 2021-09-01T02:43:01.613764
# Fetching new data for 2021-09-01T02:43:12.019544
# Fetching new data for 2021-09-01T02:43:22.396951
# Fetching new data for 2021-09-01T02:43:32.765993
# Fetching new data for 2021-09-01T02:43:43.169620
# Fetching new data for 2021-09-01T02:43:53.521068
# Fetching new data for 2021-09-01T02:44:01.892550
#
# Fetching new data for 2021-09-01T02:44:04.219826
# Fetching new data for 2021-09-01T02:44:14.597553
# Fetching new data for 2021-09-01T02:44:24.973120
# Fetching new data for 2021-09-01T02:44:35.625393
# Fetching new data for 2021-09-01T02:44:45.998088
# Fetching new data for 2021-09-01T02:44:56.373419
# Fetching new data for 2021-09-01T02:45:06.741384
# Fetching new data for 2021-09-01T02:45:17.108517
# Fetching new data for 2021-09-01T02:45:27.508143
# Fetching new data for 2021-09-01T02:45:37.890558
# Fetching new data for 2021-09-01T02:45:48.271290
# Fetching new data for 2021-09-01T02:45:58.686194
# Fetching new data for 2021-09-01T02:46:09.152833
# Fetching new data for 2021-09-01T02:46:19.513006
# Fetching new data for 2021-09-01T02:46:29.882446
# Fetching new data for 2021-09-01T02:46:40.272921
# Fetching new data for 2021-09-01T02:46:50.888993
# Fetching new data for 2021-09-01T02:47:01.311356
# Fetching new data for 2021-09-01T02:47:11.686960
# Fetching new data for 2021-09-01T02:47:22.059839
# Fetching new data for 2021-09-01T02:47:32.421184
# Fetching new data for 2021-09-01T02:47:42.823113
# Fetching new data for 2021-09-01T02:47:53.225453
# Fetching new data for 2021-09-01T02:48:03.646694
# Fetching new data for 2021-09-01T02:48:14.020565
# Fetching new data for 2021-09-01T02:48:24.450217
# Fetching new data for 2021-09-01T02:48:34.810002
# Fetching new data for 2021-09-01T02:48:45.202362
# Fetching new data for 2021-09-01T02:48:56.024706
# Fetching new data for 2021-09-01T02:49:02.400783
#
# Fetching new data for 2021-09-01T02:49:06.775539
# Fetching new data for 2021-09-01T02:49:17.202231
# Fetching new data for 2021-09-01T02:49:27.657447
# Fetching new data for 2021-09-01T02:49:38.011933
# Fetching new data for 2021-09-01T02:49:48.401141
# Fetching new data for 2021-09-01T02:49:58.811550
# Fetching new data for 2021-09-01T02:50:09.188887
# Fetching new data for 2021-09-01T02:50:19.601502
# Fetching new data for 2021-09-01T02:50:30.351606
# Fetching new data for 2021-09-01T02:50:40.752446
# Fetching new data for 2021-09-01T02:50:51.118578
# Fetching new data for 2021-09-01T02:51:01.556584
# Fetching new data for 2021-09-01T02:51:11.952030
# Fetching new data for 2021-09-01T02:51:22.339657
# Fetching new data for 2021-09-01T02:51:32.704719
# Fetching new data for 2021-09-01T02:51:43.089913
# Fetching new data for 2021-09-01T02:51:53.540029
# Fetching new data for 2021-09-01T02:52:03.910726
# Fetching new data for 2021-09-01T02:52:14.293418
# Fetching new data for 2021-09-01T02:52:24.724281
# Fetching new data for 2021-09-01T02:52:35.168363
# Fetching new data for 2021-09-01T02:52:45.603046
# Fetching new data for 2021-09-01T02:52:55.953197
# Fetching new data for 2021-09-01T02:53:06.363432
# Fetching new data for 2021-09-01T02:53:16.759618
# Fetching new data for 2021-09-01T02:53:27.125577
# Fetching new data for 2021-09-01T02:53:37.503701
# Fetching new data for 2021-09-01T02:53:47.953722
# Fetching new data for 2021-09-01T02:53:58.324869
# Fetching new data for 2021-09-01T02:54:03.692685
#
# Fetching new data for 2021-09-01T02:54:09.042697
# Fetching new data for 2021-09-01T02:54:19.404054
# Fetching new data for 2021-09-01T02:54:29.797857
# Fetching new data for 2021-09-01T02:54:40.176413
# Fetching new data for 2021-09-01T02:54:50.594232
# Fetching new data for 2021-09-01T02:55:00.974663
# Fetching new data for 2021-09-01T02:55:11.630133
# Fetching new data for 2021-09-01T02:55:22.029010
# Fetching new data for 2021-09-01T02:55:32.426308
# Fetching new data for 2021-09-01T02:55:42.875232
# Fetching new data for 2021-09-01T02:55:53.255116
# Fetching new data for 2021-09-01T02:56:03.655246
# Fetching new data for 2021-09-01T02:56:14.050371
# Fetching new data for 2021-09-01T02:56:24.439350
# Fetching new data for 2021-09-01T02:56:34.817676
# Fetching new data for 2021-09-01T02:56:45.195178
# Fetching new data for 2021-09-01T02:56:55.612316
# Fetching new data for 2021-09-01T02:57:05.977623
# Fetching new data for 2021-09-01T02:57:16.376184
# Fetching new data for 2021-09-01T02:57:27.067414
# Fetching new data for 2021-09-01T02:57:37.474112
# Fetching new data for 2021-09-01T02:57:47.867454
# Fetching new data for 2021-09-01T02:57:58.276694
# Fetching new data for 2021-09-01T02:58:08.676719
# Fetching new data for 2021-09-01T02:58:20.116776
# Fetching new data for 2021-09-01T02:58:30.476997
# Fetching new data for 2021-09-01T02:58:40.885264
# Fetching new data for 2021-09-01T02:58:51.277269
# Fetching new data for 2021-09-01T02:59:01.647031
# Fetching new data for 2021-09-01T02:59:04.997222
#
# Fetching new data for 2021-09-01T02:59:12.348744
# Fetching new data for 2021-09-01T02:59:22.707367
# Fetching new data for 2021-09-01T02:59:34.417727
# Fetching new data for 2021-09-01T02:59:44.996113
# Fetching new data for 2021-09-01T02:59:55.457717
# Fetching new data for 2021-09-01T03:00:05.930764
# Fetching new data for 2021-09-01T03:00:16.391315
# Fetching new data for 2021-09-01T03:00:26.834661
# Fetching new data for 2021-09-01T03:00:37.308261
# Fetching new data for 2021-09-01T03:00:47.770585
# Fetching new data for 2021-09-01T03:00:58.224933
# Fetching new data for 2021-09-01T03:01:08.777139
# Fetching new data for 2021-09-01T03:01:19.282375
# Fetching new data for 2021-09-01T03:01:29.758715
# Fetching new data for 2021-09-01T03:01:40.331522
# Fetching new data for 2021-09-01T03:01:50.758943
# Fetching new data for 2021-09-01T03:02:01.266707
# Fetching new data for 2021-09-01T03:02:11.676983
# Fetching new data for 2021-09-01T03:02:22.133553
# Fetching new data for 2021-09-01T03:02:32.559443
# Fetching new data for 2021-09-01T03:02:43.066503
# Fetching new data for 2021-09-01T03:02:53.516467
# Fetching new data for 2021-09-01T03:03:03.951991
# Fetching new data for 2021-09-01T03:03:14.417297
# Fetching new data for 2021-09-01T03:03:25.230201
# Fetching new data for 2021-09-01T03:03:35.735915
# Fetching new data for 2021-09-01T03:03:46.380469
# Fetching new data for 2021-09-01T03:03:56.860330
# Fetching new data for 2021-09-01T03:04:06.297934
#
# Fetching new data for 2021-09-01T03:04:07.679131
# Fetching new data for 2021-09-01T03:04:18.102970
# Fetching new data for 2021-09-01T03:04:28.518349
# Fetching new data for 2021-09-01T03:04:38.967242
# Fetching new data for 2021-09-01T03:04:49.399553
# Fetching new data for 2021-09-01T03:04:59.848525
# Fetching new data for 2021-09-01T03:05:10.511117
# Fetching new data for 2021-09-01T03:05:20.965881
# Fetching new data for 2021-09-01T03:05:31.411339
# Fetching new data for 2021-09-01T03:05:41.861837
# Fetching new data for 2021-09-01T03:05:52.285311
# Fetching new data for 2021-09-01T03:06:02.753243
# Fetching new data for 2021-09-01T03:06:13.209250
# Fetching new data for 2021-09-01T03:06:23.567078
# Fetching new data for 2021-09-01T03:06:33.982242
# Fetching new data for 2021-09-01T03:06:44.342727
# Fetching new data for 2021-09-01T03:06:54.712239
# Fetching new data for 2021-09-01T03:07:05.132606
# Fetching new data for 2021-09-01T03:07:15.486341
# Fetching new data for 2021-09-01T03:07:25.872849
# Fetching new data for 2021-09-01T03:07:36.223246
# Fetching new data for 2021-09-01T03:07:46.674591
# Fetching new data for 2021-09-01T03:07:57.253040
# Fetching new data for 2021-09-01T03:08:07.713018
# Fetching new data for 2021-09-01T03:08:18.083360
# Fetching new data for 2021-09-01T03:08:28.473893
# Fetching new data for 2021-09-01T03:08:38.838809
# Fetching new data for 2021-09-01T03:08:49.218635
# Fetching new data for 2021-09-01T03:08:59.587807
# Fetching new data for 2021-09-01T03:09:06.964651
#
# Fetching new data for 2021-09-01T03:09:10.301236
# Fetching new data for 2021-09-01T03:09:20.669981
# Fetching new data for 2021-09-01T03:09:31.094164
# Fetching new data for 2021-09-01T03:09:41.464302
# Fetching new data for 2021-09-01T03:09:51.881909
# Fetching new data for 2021-09-01T03:10:02.288023
# Fetching new data for 2021-09-01T03:10:12.901934
# Fetching new data for 2021-09-01T03:10:23.269965
# Fetching new data for 2021-09-01T03:10:33.634862
# Fetching new data for 2021-09-01T03:10:44.057689
# Fetching new data for 2021-09-01T03:10:54.458391
# Fetching new data for 2021-09-01T03:11:04.823799
# Fetching new data for 2021-09-01T03:11:15.228919
# Fetching new data for 2021-09-01T03:11:25.606023
# Fetching new data for 2021-09-01T03:11:36.003528
# Fetching new data for 2021-09-01T03:11:46.370151
# Fetching new data for 2021-09-01T03:11:56.770636
# Fetching new data for 2021-09-01T03:12:07.156002
# Fetching new data for 2021-09-01T03:12:17.674608
# Fetching new data for 2021-09-01T03:12:28.073111
# Fetching new data for 2021-09-01T03:12:38.470430
# Fetching new data for 2021-09-01T03:12:48.852272
# Fetching new data for 2021-09-01T03:12:59.310225
# Fetching new data for 2021-09-01T03:13:09.717335
# Fetching new data for 2021-09-01T03:13:20.144098
# Fetching new data for 2021-09-01T03:13:30.504149
# Fetching new data for 2021-09-01T03:13:40.888867
# Fetching new data for 2021-09-01T03:13:51.256822
# Fetching new data for 2021-09-01T03:14:01.651726
# Fetching new data for 2021-09-01T03:14:07.989038
#
# Fetching new data for 2021-09-01T03:14:12.324557
# Fetching new data for 2021-09-01T03:14:22.876888
# Fetching new data for 2021-09-01T03:14:33.274536
# Fetching new data for 2021-09-01T03:14:43.670980
# Fetching new data for 2021-09-01T03:14:54.050811
# Fetching new data for 2021-09-01T03:15:04.492318
# Fetching new data for 2021-09-01T03:15:14.892614
# Fetching new data for 2021-09-01T03:15:25.290353
# Fetching new data for 2021-09-01T03:15:35.671404
# Fetching new data for 2021-09-01T03:15:46.053874
# Fetching new data for 2021-09-01T03:15:56.402609
# Fetching new data for 2021-09-01T03:16:06.763918
# Fetching new data for 2021-09-01T03:16:17.225757
# Fetching new data for 2021-09-01T03:16:27.951599
# Fetching new data for 2021-09-01T03:16:38.321226
# Fetching new data for 2021-09-01T03:16:48.691354
# Fetching new data for 2021-09-01T03:16:59.103697
# Fetching new data for 2021-09-01T03:17:09.465788
# Fetching new data for 2021-09-01T03:17:19.926710
# Fetching new data for 2021-09-01T03:17:30.324826
# Fetching new data for 2021-09-01T03:17:40.722879
# Fetching new data for 2021-09-01T03:17:51.113179
# Fetching new data for 2021-09-01T03:18:01.572346
# Fetching new data for 2021-09-01T03:18:11.987303
# Fetching new data for 2021-09-01T03:18:22.372507
# Fetching new data for 2021-09-01T03:18:32.789962
# Fetching new data for 2021-09-01T03:18:43.290020
# Fetching new data for 2021-09-01T03:18:53.684161
# Fetching new data for 2021-09-01T03:19:04.041020
# Fetching new data for 2021-09-01T03:19:08.381634
#
# Fetching new data for 2021-09-01T03:19:14.740308
# Fetching new data for 2021-09-01T03:19:25.125535
# Fetching new data for 2021-09-01T03:19:35.523055
# Fetching new data for 2021-09-01T03:19:45.902964
# Fetching new data for 2021-09-01T03:19:56.295337
# Fetching new data for 2021-09-01T03:20:06.643659
# Fetching new data for 2021-09-01T03:20:17.026177
# Fetching new data for 2021-09-01T03:20:27.403279
# Fetching new data for 2021-09-01T03:20:37.800403
# Fetching new data for 2021-09-01T03:20:48.176154
# Fetching new data for 2021-09-01T03:20:58.597882
# Fetching new data for 2021-09-01T03:21:08.976499
# Fetching new data for 2021-09-01T03:21:19.378424
# Fetching new data for 2021-09-01T03:21:29.766033
# Fetching new data for 2021-09-01T03:21:40.422780
# Fetching new data for 2021-09-01T03:21:51.304519
# Fetching new data for 2021-09-01T03:22:01.928151
# Fetching new data for 2021-09-01T03:22:12.511704
# Fetching new data for 2021-09-01T03:22:23.051435
# Fetching new data for 2021-09-01T03:22:33.581181
# Fetching new data for 2021-09-01T03:22:44.111288
# Fetching new data for 2021-09-01T03:22:54.873362
# Fetching new data for 2021-09-01T03:23:05.323426
# Fetching new data for 2021-09-01T03:23:15.781522
# Fetching new data for 2021-09-01T03:23:26.254610
# Fetching new data for 2021-09-01T03:23:36.693016
# Fetching new data for 2021-09-01T03:23:47.184296
# Fetching new data for 2021-09-01T03:23:57.673873
# Fetching new data for 2021-09-01T03:24:08.160843
# Fetching new data for 2021-09-01T03:24:09.554927
#
# Fetching new data for 2021-09-01T03:24:18.995834
# Fetching new data for 2021-09-01T03:24:29.483546
# Fetching new data for 2021-09-01T03:24:39.934147
# Fetching new data for 2021-09-01T03:24:50.360554
# Fetching new data for 2021-09-01T03:25:01.010555
# Fetching new data for 2021-09-01T03:25:11.515672
# Fetching new data for 2021-09-01T03:25:21.974358
# Fetching new data for 2021-09-01T03:25:32.405533
# Fetching new data for 2021-09-01T03:25:42.911102
# Fetching new data for 2021-09-01T03:25:53.343235
# Fetching new data for 2021-09-01T03:26:03.810022
# Fetching new data for 2021-09-01T03:26:14.270497
# Fetching new data for 2021-09-01T03:26:24.709881
# Fetching new data for 2021-09-01T03:26:35.126436
# Fetching new data for 2021-09-01T03:26:45.564518
# Fetching new data for 2021-09-01T03:26:55.976335
# Fetching new data for 2021-09-01T03:27:06.428809
# Fetching new data for 2021-09-01T03:27:16.906297
# Fetching new data for 2021-09-01T03:27:27.379327
# Fetching new data for 2021-09-01T03:27:37.851380
# Fetching new data for 2021-09-01T03:27:48.281557
# Fetching new data for 2021-09-01T03:27:58.732918
# Fetching new data for 2021-09-01T03:28:09.173883
# Fetching new data for 2021-09-01T03:28:19.652571
# Fetching new data for 2021-09-01T03:28:30.079790
# Fetching new data for 2021-09-01T03:28:40.556967
# Fetching new data for 2021-09-01T03:28:50.985748
# Fetching new data for 2021-09-01T03:29:01.426150
# Fetching new data for 2021-09-01T03:29:10.913092
#
# Fetching new data for 2021-09-01T03:29:12.432572
# Fetching new data for 2021-09-01T03:29:23.003651
# Fetching new data for 2021-09-01T03:29:33.467706
# Fetching new data for 2021-09-01T03:29:43.877907
# Fetching new data for 2021-09-01T03:29:54.308895
# Fetching new data for 2021-09-01T03:30:04.782674
# Fetching new data for 2021-09-01T03:30:15.170632
# Fetching new data for 2021-09-01T03:30:25.564933
# Fetching new data for 2021-09-01T03:30:35.946958
# Fetching new data for 2021-09-01T03:30:46.309736
# Fetching new data for 2021-09-01T03:30:56.781681
# Fetching new data for 2021-09-01T03:31:07.158261
# Fetching new data for 2021-09-01T03:31:17.877051
# Fetching new data for 2021-09-01T03:31:28.281857
# Fetching new data for 2021-09-01T03:31:38.680270
# Fetching new data for 2021-09-01T03:31:49.077330
# Fetching new data for 2021-09-01T03:31:59.481113
# Fetching new data for 2021-09-01T03:32:09.882668
# Fetching new data for 2021-09-01T03:32:20.282087
# Fetching new data for 2021-09-01T03:32:30.663792
# Fetching new data for 2021-09-01T03:32:41.020890
# Fetching new data for 2021-09-01T03:32:51.405052
# Fetching new data for 2021-09-01T03:33:01.773987
# Fetching new data for 2021-09-01T03:33:12.196456
# Fetching new data for 2021-09-01T03:33:22.573914
# Fetching new data for 2021-09-01T03:33:33.270862
# Fetching new data for 2021-09-01T03:33:43.659177
# ...
# Fetching new data for 2021-09-01T10:49:33.387088
# Fetching new data for 2021-09-01T10:49:43.783197
# Fetching new data for 2021-09-01T10:49:54.190536
# Fetching new data for 2021-09-01T10:50:04.580909
# Fetching new data for 2021-09-01T10:50:14.954350
# Fetching new data for 2021-09-01T10:50:25.358064
# Fetching new data for 2021-09-01T10:50:35.743927
# Fetching new data for 2021-09-01T10:50:37.084010
#
# Fetching new data for 2021-09-01T10:50:46.510305
# Fetching new data for 2021-09-01T10:50:56.884262
# Fetching new data for 2021-09-01T10:51:07.361153
# Fetching new data for 2021-09-01T10:51:17.775824
# Fetching new data for 2021-09-01T10:51:28.166878
# Fetching new data for 2021-09-01T10:51:38.541816
# Fetching new data for 2021-09-01T10:51:48.939322
# Fetching new data for 2021-09-01T10:51:59.326146
# Fetching new data for 2021-09-01T10:52:09.726599
# Fetching new data for 2021-09-01T10:52:20.173794
# Fetching new data for 2021-09-01T10:52:30.579606
# Fetching new data for 2021-09-01T10:52:41.130867
# Fetching new data for 2021-09-01T10:52:51.541806
# Fetching new data for 2021-09-01T10:53:01.936015
# Fetching new data for 2021-09-01T10:53:12.326859
# Fetching new data for 2021-09-01T10:53:22.817326
# Fetching new data for 2021-09-01T10:53:33.206110
# Fetching new data for 2021-09-01T10:53:43.592980
# Fetching new data for 2021-09-01T10:53:53.986712
# Fetching new data for 2021-09-01T10:54:04.417977
# Fetching new data for 2021-09-01T10:54:15.240547
# Fetching new data for 2021-09-01T10:54:25.637231
# Fetching new data for 2021-09-01T10:54:36.041916
# Fetching new data for 2021-09-01T10:54:46.437497
# Fetching new data for 2021-09-01T10:54:56.861804
# Fetching new data for 2021-09-01T10:55:07.278632
# Fetching new data for 2021-09-01T10:55:17.688678
# Fetching new data for 2021-09-01T10:55:28.090167
# Fetching new data for 2021-09-01T10:55:37.527919
#
# Fetching new data for 2021-09-01T10:55:38.851305
# Fetching new data for 2021-09-01T10:55:49.245136
# Fetching new data for 2021-09-01T10:55:59.636229
# Fetching new data for 2021-09-01T10:56:10.019896
# Fetching new data for 2021-09-01T10:56:20.472809
# Fetching new data for 2021-09-01T10:56:30.858623
# Fetching new data for 2021-09-01T10:56:41.293844
# Fetching new data for 2021-09-01T10:56:51.770310
# Fetching new data for 2021-09-01T10:57:02.214509
# Fetching new data for 2021-09-01T10:57:12.627977
# Fetching new data for 2021-09-01T10:57:23.088459
# Fetching new data for 2021-09-01T10:57:33.492626
# Fetching new data for 2021-09-01T10:57:43.931252
# Fetching new data for 2021-09-01T10:57:54.346015
# Fetching new data for 2021-09-01T10:58:04.740280
# Fetching new data for 2021-09-01T10:58:15.110568
# Fetching new data for 2021-09-01T10:58:25.523496
# Fetching new data for 2021-09-01T10:58:35.929793
# Fetching new data for 2021-09-01T10:58:46.378018
# Fetching new data for 2021-09-01T10:58:56.773263
# Fetching new data for 2021-09-01T10:59:07.158564
# Fetching new data for 2021-09-01T10:59:17.543366
# Fetching new data for 2021-09-01T10:59:28.156029
# Fetching new data for 2021-09-01T10:59:38.513025
# Fetching new data for 2021-09-01T10:59:48.877381
# Fetching new data for 2021-09-01T10:59:59.331434
# Fetching new data for 2021-09-01T11:00:09.742648
# Fetching new data for 2021-09-01T11:00:20.104160
# Fetching new data for 2021-09-01T11:00:30.504307
# Fetching new data for 2021-09-01T11:00:37.891868
#
# Fetching new data for 2021-09-01T11:00:41.238717
# Fetching new data for 2021-09-01T11:00:51.727104
# Fetching new data for 2021-09-01T11:01:02.142117
# Fetching new data for 2021-09-01T11:01:12.778379
# Fetching new data for 2021-09-01T11:01:23.192322
# Fetching new data for 2021-09-01T11:01:33.684530
# Fetching new data for 2021-09-01T11:01:44.073934
# Fetching new data for 2021-09-01T11:01:54.478114
# Fetching new data for 2021-09-01T11:02:04.874206
# Fetching new data for 2021-09-01T11:02:15.278310
# Fetching new data for 2021-09-01T11:02:25.724328
# Fetching new data for 2021-09-01T11:02:36.450386
# Fetching new data for 2021-09-01T11:02:46.928658
# Fetching new data for 2021-09-01T11:02:57.378680
# Fetching new data for 2021-09-01T11:03:07.830000
# Fetching new data for 2021-09-01T11:03:18.415103
# Fetching new data for 2021-09-01T11:03:29.056658
# Fetching new data for 2021-09-01T11:03:39.502196
# Fetching new data for 2021-09-01T11:03:50.012360
# Fetching new data for 2021-09-01T11:04:00.456424
# Fetching new data for 2021-09-01T11:04:10.994050
# Fetching new data for 2021-09-01T11:04:21.448882
# Fetching new data for 2021-09-01T11:04:31.907358
# Fetching new data for 2021-09-01T11:04:42.375825
# Fetching new data for 2021-09-01T11:04:52.856954
# Fetching new data for 2021-09-01T11:05:03.329798
# Fetching new data for 2021-09-01T11:05:13.799473
# Fetching new data for 2021-09-01T11:05:24.279743
# Fetching new data for 2021-09-01T11:05:34.747423
# Fetching new data for 2021-09-01T11:05:39.167449
#
# Fetching new data for 2021-09-01T11:05:45.607492
# Fetching new data for 2021-09-01T11:05:56.030599
# Fetching new data for 2021-09-01T11:06:06.595240
# Fetching new data for 2021-09-01T11:06:17.036363
# Fetching new data for 2021-09-01T11:06:27.530888
# Fetching new data for 2021-09-01T11:06:37.987528
# Fetching new data for 2021-09-01T11:06:48.427147
# Fetching new data for 2021-09-01T11:06:59.032258
# Fetching new data for 2021-09-01T11:07:09.430363
# Fetching new data for 2021-09-01T11:07:19.858455
# Fetching new data for 2021-09-01T11:07:30.413882
# Fetching new data for 2021-09-01T11:07:40.801457
# Fetching new data for 2021-09-01T11:07:51.277779
# Fetching new data for 2021-09-01T11:08:01.696512
# Fetching new data for 2021-09-01T11:08:12.178023
# Fetching new data for 2021-09-01T11:08:22.582177
# Fetching new data for 2021-09-01T11:08:33.019518
# Fetching new data for 2021-09-01T11:08:43.396848
# Fetching new data for 2021-09-01T11:08:53.778404
# Fetching new data for 2021-09-01T11:09:04.182311
# Fetching new data for 2021-09-01T11:09:14.559626
# Fetching new data for 2021-09-01T11:09:25.009757
# Fetching new data for 2021-09-01T11:09:35.747450
# Fetching new data for 2021-09-01T11:09:46.170185
# Fetching new data for 2021-09-01T11:09:56.632067
# Fetching new data for 2021-09-01T11:10:07.042131
# Fetching new data for 2021-09-01T11:10:17.430463
# Fetching new data for 2021-09-01T11:10:27.855235
# Fetching new data for 2021-09-01T11:10:38.279452
# Fetching new data for 2021-09-01T11:10:39.659144
#
# Fetching new data for 2021-09-01T11:10:49.070643
# Fetching new data for 2021-09-01T11:10:59.439963
# Fetching new data for 2021-09-01T11:11:09.899305
# Fetching new data for 2021-09-01T11:11:20.383975
# Fetching new data for 2021-09-01T11:11:30.753378
# Fetching new data for 2021-09-01T11:11:41.120406
# Fetching new data for 2021-09-01T11:11:51.540574
# Fetching new data for 2021-09-01T11:12:02.071198
# Fetching new data for 2021-09-01T11:12:12.426118
# Fetching new data for 2021-09-01T11:12:22.790101
# Fetching new data for 2021-09-01T11:12:33.168342
# Fetching new data for 2021-09-01T11:12:43.504142
# Fetching new data for 2021-09-01T11:12:53.902199
# Fetching new data for 2021-09-01T11:13:04.249806
# Fetching new data for 2021-09-01T11:13:14.600356
# Fetching new data for 2021-09-01T11:13:24.969739
# Fetching new data for 2021-09-01T11:13:35.383741
# Fetching new data for 2021-09-01T11:13:45.712432
# Fetching new data for 2021-09-01T11:13:56.116633
# Fetching new data for 2021-09-01T11:14:06.471804
# Fetching new data for 2021-09-01T11:14:16.831151
# Fetching new data for 2021-09-01T11:14:27.206537
# Fetching new data for 2021-09-01T11:14:37.606124
# Fetching new data for 2021-09-01T11:14:47.961598
# Fetching new data for 2021-09-01T11:14:58.350701
# Fetching new data for 2021-09-01T11:15:08.745705
# Fetching new data for 2021-09-01T11:15:19.114729
# Fetching new data for 2021-09-01T11:15:29.496714
# Fetching new data for 2021-09-01T11:15:39.899526
# Fetching new data for 2021-09-01T11:15:41.225663
#
# Fetching new data for 2021-09-01T11:15:50.597067
# Fetching new data for 2021-09-01T11:16:01.017888
# Fetching new data for 2021-09-01T11:16:11.405496
# Fetching new data for 2021-09-01T11:16:21.794360
# Fetching new data for 2021-09-01T11:16:32.207887
# Fetching new data for 2021-09-01T11:16:42.626041
# Fetching new data for 2021-09-01T11:16:53.039352
# Fetching new data for 2021-09-01T11:17:03.452042
# Fetching new data for 2021-09-01T11:17:13.852070
# Fetching new data for 2021-09-01T11:17:24.364654
# Fetching new data for 2021-09-01T11:17:34.802291
# Fetching new data for 2021-09-01T11:17:45.304626
# Fetching new data for 2021-09-01T11:17:55.742941
# Fetching new data for 2021-09-01T11:18:06.172753
# Fetching new data for 2021-09-01T11:18:16.740349
# Fetching new data for 2021-09-01T11:18:27.852919
# Fetching new data for 2021-09-01T11:18:38.281607
# Fetching new data for 2021-09-01T11:18:48.715523
# Fetching new data for 2021-09-01T11:18:59.150702
# Fetching new data for 2021-09-01T11:19:09.598722
# Fetching new data for 2021-09-01T11:19:20.094720
# Fetching new data for 2021-09-01T11:19:30.527745
# Fetching new data for 2021-09-01T11:19:40.926979
# Fetching new data for 2021-09-01T11:19:51.355774
# Fetching new data for 2021-09-01T11:20:01.839148
# Fetching new data for 2021-09-01T11:20:12.368807
# Fetching new data for 2021-09-01T11:20:22.788208
# Fetching new data for 2021-09-01T11:20:33.241736
# Fetching new data for 2021-09-01T11:20:41.666715
#
# Fetching new data for 2021-09-01T11:20:44.084215
# Fetching new data for 2021-09-01T11:20:54.485874
# Fetching new data for 2021-09-01T11:21:04.948058
# Fetching new data for 2021-09-01T11:21:15.376606
# Fetching new data for 2021-09-01T11:21:25.859555
# Fetching new data for 2021-09-01T11:21:36.257773
# Fetching new data for 2021-09-01T11:21:46.672875
# Fetching new data for 2021-09-01T11:21:57.093154
# Fetching new data for 2021-09-01T11:22:07.493161
# Fetching new data for 2021-09-01T11:22:17.982732
# Fetching new data for 2021-09-01T11:22:28.393342
# Fetching new data for 2021-09-01T11:22:38.756329
# Fetching new data for 2021-09-01T11:22:49.268865
# Fetching new data for 2021-09-01T11:22:59.699994
# Fetching new data for 2021-09-01T11:23:10.093338
# Fetching new data for 2021-09-01T11:23:20.505832
# Fetching new data for 2021-09-01T11:23:30.899970
# Fetching new data for 2021-09-01T11:23:41.277250
# Fetching new data for 2021-09-01T11:23:51.699887
# Fetching new data for 2021-09-01T11:24:02.092698
# Fetching new data for 2021-09-01T11:24:12.526203
# Fetching new data for 2021-09-01T11:24:22.926052
# Fetching new data for 2021-09-01T11:24:33.590549
# Fetching new data for 2021-09-01T11:24:44.026178
# Fetching new data for 2021-09-01T11:24:54.461431
# Fetching new data for 2021-09-01T11:25:04.841133
# Fetching new data for 2021-09-01T11:25:15.260520
# Fetching new data for 2021-09-01T11:25:25.739854
# Fetching new data for 2021-09-01T11:25:36.147691
# Fetching new data for 2021-09-01T11:25:42.579879
#
# Fetching new data for 2021-09-01T11:25:46.959572
# Fetching new data for 2021-09-01T11:25:57.325691
# Fetching new data for 2021-09-01T11:26:07.707712
# Fetching new data for 2021-09-01T11:26:18.095713
# Fetching new data for 2021-09-01T11:26:28.491581
# Fetching new data for 2021-09-01T11:26:38.889113
# Fetching new data for 2021-09-01T11:26:49.261777
# Fetching new data for 2021-09-01T11:26:59.699736
# Fetching new data for 2021-09-01T11:27:10.100209
# Fetching new data for 2021-09-01T11:27:20.471549
# Fetching new data for 2021-09-01T11:27:30.985805
# Fetching new data for 2021-09-01T11:27:41.412824
# Fetching new data for 2021-09-01T11:27:51.796395
# Fetching new data for 2021-09-01T11:28:02.597150
# Fetching new data for 2021-09-01T11:28:13.031717
# Fetching new data for 2021-09-01T11:28:23.509976
# Fetching new data for 2021-09-01T11:28:33.913173
# Fetching new data for 2021-09-01T11:28:44.496619
# Fetching new data for 2021-09-01T11:28:54.848008
# Fetching new data for 2021-09-01T11:29:05.242358
# Fetching new data for 2021-09-01T11:29:15.622167
# Fetching new data for 2021-09-01T11:29:26.124281
# Fetching new data for 2021-09-01T11:29:36.500561
# Fetching new data for 2021-09-01T11:29:46.826490
# Fetching new data for 2021-09-01T11:29:57.236511
# Fetching new data for 2021-09-01T11:30:07.606327
# Fetching new data for 2021-09-01T11:30:17.962125
# Fetching new data for 2021-09-01T11:30:28.361936
# Fetching new data for 2021-09-01T11:30:38.813392
# Fetching new data for 2021-09-01T11:30:43.297902
#
# Fetching new data for 2021-09-01T11:30:49.667644
# Fetching new data for 2021-09-01T11:31:00.113248
# Fetching new data for 2021-09-01T11:31:10.509131
# Fetching new data for 2021-09-01T11:31:20.949711
# Fetching new data for 2021-09-01T11:31:31.318302
# Fetching new data for 2021-09-01T11:31:41.663860
# Fetching new data for 2021-09-01T11:31:52.181459
# Fetching new data for 2021-09-01T11:32:02.552415
# Fetching new data for 2021-09-01T11:32:12.919703
# Fetching new data for 2021-09-01T11:32:23.319444
# Fetching new data for 2021-09-01T11:32:33.701082
# Fetching new data for 2021-09-01T11:32:44.066372
# Fetching new data for 2021-09-01T11:32:54.428732
# 502 Server Error: Bad Gateway for url: https://nummus.robinhood.com/currency_pairs/
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-898bb1985c14> in <module>
#      90
#      91 while True:
# ---> 92     schedule.run_pending()
#      93     time.sleep(1)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/schedule/__init__.py in run_pending()
#     778     :data:`default scheduler instance <default_scheduler>`.
#     779     """
# --> 780     default_scheduler.run_pending()
#     781
#     782
#
# ~/opt/miniconda3/lib/python3.8/site-packages/schedule/__init__.py in run_pending(self)
#      98         runnable_jobs = (job for job in self.jobs if job.should_run)
#      99         for job in sorted(runnable_jobs):
# --> 100             self._run_job(job)
#     101
#     102     def run_all(self, delay_seconds: int = 0) -> None:
#
# ~/opt/miniconda3/lib/python3.8/site-packages/schedule/__init__.py in _run_job(self, job)
#     170
#     171     def _run_job(self, job: "Job") -> None:
# --> 172         ret = job.run()
#     173         if isinstance(ret, CancelJob) or ret is CancelJob:
#     174             self.cancel_job(job)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/schedule/__init__.py in run(self)
#     659
#     660         logger.debug("Running job %s", self)
# --> 661         ret = self.job_func()
#     662         self.last_run = datetime.datetime.now()
#     663         self._schedule_next_run()
#
# <ipython-input-9-d30626099426> in run_bot()
#      73 def run_bot():
#      74     print(f"Fetching new data for {datetime.now().isoformat()}")
# ---> 75     df = pd.DataFrame.from_dict(r.crypto.get_crypto_historicals('DOGE', interval='5minute', span='week', bounds='24_7', info=None)).drop(columns=['session','interpolated','symbol']).tail(100).reset_index(drop=True)
#      76     bar = []
#      77     for k,v in df.begins_at.items():
#
# ~/opt/miniconda3/lib/python3.8/site-packages/robin_stocks/helper.py in login_wrapper(*args, **kwargs)
#      38             raise Exception('{} can only be called when logged in'.format(
#      39                 func.__name__))
# ---> 40         return(func(*args, **kwargs))
#      41     return(login_wrapper)
#      42
#
# ~/opt/miniconda3/lib/python3.8/site-packages/robin_stocks/crypto.py in get_crypto_historicals(symbol, interval, span, bounds, info)
#     210
#     211     symbol = helper.inputs_to_set(symbol)
# --> 212     id = get_crypto_info(symbol[0], info='id')
#     213     url = urls.crypto_historical(id)
#     214     payload = {'interval': interval,
#
# ~/opt/miniconda3/lib/python3.8/site-packages/robin_stocks/crypto.py in get_crypto_info(symbol, info)
#     101     url = urls.crypto_currency_pairs()
#     102     data = helper.request_get(url, 'results')
# --> 103     data = [x for x in data if x['asset_currency']['code'] == symbol]
#     104     if len(data) > 0:
#     105         data = data[0]
#
# ~/opt/miniconda3/lib/python3.8/site-packages/robin_stocks/crypto.py in <listcomp>(.0)
#     101     url = urls.crypto_currency_pairs()
#     102     data = helper.request_get(url, 'results')
# --> 103     data = [x for x in data if x['asset_currency']['code'] == symbol]
#     104     if len(data) > 0:
#     105         data = data[0]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#En fin...
